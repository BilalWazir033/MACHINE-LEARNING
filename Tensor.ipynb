# %%
import numpy as np

# %% [markdown]
# ### 0D Tensor or Scalar

# %%
a=np.array(4)

# %%
a
# Out:
# array(4)

# %%
a.ndim # to check dimensions
# Out:
# 0

# %% [markdown]
# ### 1D Tensor or Vector

# %%
arr=np.array([2,3,6,7,4])

# %%
arr
# Out:
# array([2, 3, 6, 7, 4])

# %%
arr.ndim
# Out:
# 1

# %% [markdown]
# ### 2D Tensor or Matrices

# %%
mat=np.array([[2,5,6],[4,6,7],[4,7,2]])

# %%
mat
# Out:
# array([[2, 5, 6],
#        [4, 6, 7],
#        [4, 7, 2]])

# %%
mat.ndim
# Out:
# 2
