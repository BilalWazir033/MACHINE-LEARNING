# %%
import pandas as pd

# %%
pd.read_json("train.json")
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')
# Out:
#                              provider  \
# INR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ..                                ...
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWG  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# INR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ZMW  https://www.exchangerate-api.com/docs/free
# ZWG  https://www.exchangerate-api.com/docs/free
# ZWL  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date  \
# INR  https://www.exchangerate-api.com/terms  INR 2026-04-18
# AED  https://www.exchangerate-api.com/terms  INR 2026-04-18
# AFN  https://www.exchangerate-api.com/terms  INR 2026-04-18
# ALL  https://www.exchangerate-api.com/terms  INR 2026-04-18
# AMD  https://www.exchangerate-api.com/terms  INR 2026-04-18
# ..                                      ...  ...        ...
# YER  https://www.exchangerate-api.com/terms  INR 2026-04-18
# ZAR  https://www.exchangerate-api.com/terms  INR 2026-04-18
# ZMW  https://www.exchangerate-api.com/terms  INR 2026-04-18
# ZWG  https://www.exchangerate-api.com/terms  INR 2026-04-18
# ZWL  https://www.exchangerate-api.com/terms  INR 2026-04-18
#
#      time_last_updated   rates
# INR         1776470401  1.0000
# AED         1776470401  0.0395
# AFN         1776470401  0.6910
# ALL         1776470401  0.8700
# AMD         1776470401  4.0300
# ..                 ...     ...
# YER         1776470401  2.5600
# ZAR         1776470401  0.1760
# ZMW         1776470401  0.2060
# ZWG         1776470401  0.2710
# ZWL         1776470401  0.2710
#
# [166 rows x 7 columns]

# %%
# !python -m pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mysql-connector-python in C:\Users\MY\AppData\Roaming\Python\Python313\site-packages (9.6.0)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\MY\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\MY\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\MY\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\MY\AppData\Roaming\Python\Python313\site-packages)

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='Bilal@2025',   # put your real password here
    database='world'
)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 conn = mysql.connector.connect(
#       2     host='localhost',
#       3     user='root',
#       4     password='Bilal@2025',   # put your real password here
#       5     database='world'
#       6 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mysql\connector\pooling.py:323, in connect(*args, **kwargs)
#     321 if CMySQLConnection and not use_pure:
#     322     return CMySQLConnection(*args, **kwargs)
# --> 323 return MySQLConnection(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mysql\connector\connection.py:185, in MySQLConnection.__init__(self, **kwargs)
#     183 if kwargs:
#     184     try:
# --> 185         self.connect(**kwargs)
#     186     except Exception:
#     187         # Tidy-up underlying socket on failure
#     188         self.close()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mysql\connector\abstracts.py:1604, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1601     self.config(**kwargs)
#    1603 self.disconnect()
# -> 1604 self._open_connection()
#    1606 charset, collation = (
#    1607     kwargs.pop("charset", None),
#    1608     kwargs.pop("collation", None),
#    1609 )
#    1610 if charset or collation:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mysql\connector\connection.py:411, in MySQLConnection._open_connection(self)
#     406     if isinstance(err, (ReadTimeoutError, WriteTimeoutError)):
#     407         raise ConnectionTimeoutError(
#     408             errno=err.errno,
#     409             msg=err.msg,
#     410         ) from err
# --> 411     raise err
#     412 finally:
#     413     # as the connection is established, set back the read
#     414     # and write timeouts to the original value
#     415     self.read_timeout = stored_read_timeout
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mysql\connector\connection.py:388, in MySQLConnection._open_connection(self)
#     385 self._do_handshake()
#     387 # start authentication negotiation
# --> 388 self._do_auth(
#     389     self._user,
#     390     self._password,
#     391     self._database,
#     392     self._client_flags,
#     393     self._ssl,
#     394     self._conn_attrs,
#     395 )
#     396 self.converter_class = self._converter_class
#     398 if self._client_flags & ClientFlag.COMPRESS:
#     399     # update the network layer accordingly
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mysql\connector\connection.py:320, in MySQLConnection._do_auth(self, username, password, database, client_flags, ssl_options, conn_attrs)
#     309 # Add the custom configurations required by specific auth plugins
#     310 self._authenticator.update_plugin_config(
#     311     config={
#     312         "krb_service_principal": self._krb_service_principal,
#    (...)    317     }
#     318 )
# --> 320 ok_pkt = self._authenticator.authenticate(
#     321     sock=self._socket,
#     322     handshake=self._handshake,
#     323     username=username,
#     324     password1=password,
#     325     password2=self._password2,
#     326     password3=self._password3,
#     327     database=database,
#     328     charset=self._charset_id,
#     329     client_flags=client_flags,
#     330     auth_plugin=self._auth_plugin,
#     331     auth_plugin_class=self._auth_plugin_class,
#     332     conn_attrs=conn_attrs,
#     333 )
#     334 self._handle_ok(ok_pkt)
#     336 if not (client_flags & ClientFlag.CONNECT_WITH_DB) and database:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mysql\connector\authentication.py:381, in MySQLAuthenticator.authenticate(self, sock, handshake, username, password1, password2, password3, database, charset, client_flags, max_allowed_packet, auth_plugin, auth_plugin_class, conn_attrs, is_change_user_request, read_timeout, write_timeout)
#     378 # server replies back
#     379 pkt = bytes(sock.recv(read_timeout))
# --> 381 ok_pkt = self._handle_server_response(sock, pkt)
#     382 if ok_pkt is None:
#     383     raise InterfaceError("Got a NULL ok_pkt") from None
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mysql\connector\authentication.py:287, in MySQLAuthenticator._handle_server_response(self, sock, pkt)
#     284     return self._mfa_n_factor(sock, pkt)
#     286 if pkt[4] == ERR_STATUS:
# --> 287     raise get_exception(pkt)
#     289 return None
#
# ProgrammingError: 1045 (28000): Access denied for user 'root'@'localhost' (using password: YES)

# %%
print(conn.is_connected())

# %%
df = pd.read_sql_query("SELECT * FROM countrylanguage",conn)
